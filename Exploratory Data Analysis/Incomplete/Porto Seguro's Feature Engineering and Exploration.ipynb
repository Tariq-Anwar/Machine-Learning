# %% [markdown]
# ## Porto Seguro's Feature Engineering and Exploration

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Data
path= r"D:\My Computer\DATA\Porto_Seguros" #Windows
#path= r"/Users/nicapotato/Desktop/Data/House" #Mac

# Load, combine, save index, delete excess data from memory
train_df = pd.read_csv(open(os.path.join(path, "train.csv"), "r"), index_col='id')
test_df = pd.read_csv(open(os.path.join(path, "test.csv"), "r"), index_col='id')
print(train_df.shape, test_df.shape)
label = train_df['target'].copy()
train_df = train_df.drop('target', axis=1)
traindex = train_df.index
testdex = test_df.index
df = pd.concat([train_df,test_df])
# del train_df
del test_df
# Out:
# (595212, 58) (892816, 57)

# %%
df.head()
# Out:
#     ps_ind_01  ps_ind_02_cat  ps_ind_03  ps_ind_04_cat  ps_ind_05_cat  \
# id
# 7           2              2          5              1              0
# 9           1              1          7              0              0
# 13          5              4          9              1              0
# 16          0              1          2              0              0
# 17          0              2          0              1              0
#
#     ps_ind_06_bin  ps_ind_07_bin  ps_ind_08_bin  ps_ind_09_bin  ps_ind_10_bin  \
# id
# 7               0              1              0              0              0
# 9               0              0              1              0              0
# 13              0              0              1              0              0
# 16              1              0              0              0              0
# 17              1              0              0              0              0
#
#          ...        ps_calc_11  ps_calc_12  ps_calc_13  ps_calc_14  \
# id       ...
# 7        ...                 9           1           5           8
# 9        ...                 3           1           1           9
# 13       ...                 4           2           7           7
# 16       ...                 2           2           4           9
# 17       ...                 3           1           1           3
#
#     ps_calc_15_bin  ps_calc_16_bin  ps_calc_17_bin  ps_calc_18_bin  \
# id
# 7                0               1               1               0
# 9                0               1               1               0
# 13               0               1               1               0
# 16               0               0               0               0
# 17               0               0               0               1
#
#     ps_calc_19_bin  ps_calc_20_bin
# id
# 7                0               1
# 9                1               0
# 13               1               0
# 16               0               0
# 17               1               0
#
# [5 rows x 57 columns]

# %%
df.info()

# %%
df.describe(include=['O'])

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
sns.set(style="white")


# Compute the correlation matrix
corr = train.corr()


# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1eb122b9cdd1> in <module>()
#       3
#       4 # Compute the correlation matrix
# ----> 5 corr = train.corr()
#       6
#       7
#
# NameError: name 'train' is not defined
