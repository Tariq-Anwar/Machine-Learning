# %% [markdown]
# # Bureau of Labor Statistics: Processing Producer Price Index
# _By Nick Brooks, Date: December 2017_
#
# ## Content
# 1. [Reading Multiple Files](#p1)
# 1. Regular Expressions
# 1. [New Variables: Age (how long since present), Minimum (Starting Year)](#p3)
# 1. [Datetime Conversion](#p4)
# 1. [Merging datasets by ID to append important categorizing information](#p5)
# 1. [Normalize: Calculate value difference by Series_ID](#p6)
# 1. [Data Visualization](#p7)

# %%
# General
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import os 

# Viz
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Warnings OFF
import warnings
warnings.filterwarnings('ignore')

# %%
# File Names
ppi_df = pd.DataFrame(os.listdir('../input/ppi/'), columns=["name"])

# Determine file purpose (prices or supportive files)
ppi_df["type"] = ppi_df.name.apply(lambda x: x.split('.')[1])

# Extract Industry Name
ppi_df["industry"] = "none"
ppi_df["industry"] = ppi_df.loc[ppi_df.type == "data","name"].apply(lambda x: x.split('.')[3])

# %% [markdown]
# ## Reading Multiple Files and Concatenate
# <a id="ch1"></a>

# %%
# Read Name and Industry Name
indus_file = ppi_df.loc[ppi_df.type == "data",["name","industry"]]

out = pd.DataFrame(index=None)
for index, row in indus_file.iterrows():
    df = pd.read_csv("../input/ppi/{}".format(row[0]),
                               usecols=["series_id","year","period","value"])
    df["industry"] = row[1]
    df.period = df.period.str.replace("M","").astype(int)
    out = pd.concat([out, df], axis=0)
out.shape
# Out:
# (2250958, 5)

# %% [markdown]
# ## New Variables: Age (how long since present), Minimum (Starting Year)
# <a id="ch3"></a>

# %%
# Find minimum by Year
out["minimum"] = 'none'
indus_min = []
# Loop by Industry
for x in out.industry.unique():
    # Minimum
    mini = out.loc[out.industry=="Wood", "year"].min()
    # List of Minimums
    indus_min.append([x,mini])
    # Variable
    out.minimum[out.industry==x] = mini
indus_min= pd.DataFrame(indus_min, columns=["Industry","MinimumYear"])

# Time from present
out["frompresent"]= (2017 - out.year)
out['age'] = (out.year - out.minimum)

# %% [markdown]
# ## Datetime Conversion
# <a id="ch4"></a>

# %%
# Annual Aggregates
aggregate = out.loc[out.period>12,:]

# Remove Aggregates, saved under month 13, to convert to date time
out = out[out.period != 13]

# Convert to pandas datetime format
out.loc[:,'date'] = pd.to_datetime(out.apply(
    lambda x:'%s-%s-01' % (x['year'],x['period']),axis=1))

# %%
# View Supportive Files
helper_file = ppi_df.loc[(ppi_df.type != "data") &
    (~ppi_df['name'].isin(["pc.contacts","pc.txt"])),["name"]]

print(ppi_df.loc[ppi_df.type!= "data",["name","type"]])

for index, row in helper_file.iterrows():
    print("\n",row[0])
    df = pd.read_csv("../input/ppi/{}".format(row[0]))
    print(df.head())
# Out:
#                name      type
# 1     pc.period.csv    period
# 15   pc.product.csv   product
# 19           pc.txt       txt
# 42  pc.footnote.csv  footnote
# 57    pc.series.csv    series
# 60  pc.industry.csv  industry
# 77      pc.contacts  contacts
#
#  pc.period.csv
#    Unnamed: 0 period period_abbr period_name
# 0           0    M01         JAN     January
# 1           1    M02         FEB    February
# 2           2    M03         MAR       March
# 3           3    M04         APR       April
# 4           4    M05         MAY         May
#
#  pc.product.csv
#   Unnamed: 0 industry_code            product_code  product_name
# 0     1133--        1133--                 Logging           NaN
# 1     11331-        11331-                 Logging           NaN
# 2     113310        113310                 Logging           NaN
# 3     113310       113310M  Miscellaneous receipts           NaN
# 4     113310      113310MM  Miscellaneous receipts           NaN
#
#  pc.footnote.csv
#   Unnamed: 0                                      footnote_code  footnote_text
# 0          P  Preliminary. All indexes are subject to revisi...            NaN
# 1          R                                            Revised            NaN
#
#  pc.series.csv
#    Unnamed: 0                       series_id industry_code product_code  \
# 0           0  PCU1133--1133--                       1133--       1133--
# 1           1  PCU11331-11331-                       11331-       11331-
# 2           2  PCU113310113310                       113310       113310
# 3           3  PCU113310113310M                      113310      113310M
# 4           4  PCU113310113310MM                     113310     113310MM
#
#   seasonal  base_date footnote_codes  begin_year begin_period  end_year  \
# 0        U     198112                       1981          M12      2017
# 1        U     198112                       1981          M12      2017
# 2        U     198112                       1981          M12      2017
# 3        U     198606                       1986          M06      2017
# 4        U     198606                       1986          M06      1998
#
#   end_period
# 0        M07
# 1        M07
# 2        M07
# 3        M07
# 4        M08
#
#  pc.industry.csv
#   Unnamed: 0           industry_code  industry_name
# 0     1133--                 Logging            NaN
# 1     11331-                 Logging            NaN
# 2     113310                 Logging            NaN
# 3     211---  Oil and gas extraction            NaN
# 4     2111--  Oil and gas extraction            NaN

# %%
# Load Helper Files to ID product types
series = pd.read_csv("../input/ppi/pc.series.csv",index_col=0)
industry = pd.read_csv("../input/ppi/pc.industry.csv").iloc[:,0:2]
industry.columns = ["industry_code","industry_name"]
product = pd.read_csv("../input/ppi/pc.product.csv").iloc[:,0:3]
product.columns = ["industry_code","product_code","product_name"]

# %% [markdown]
# ## Merging datasets by ID to append important categorizing information
# <a id="ch5"></a>

# %%
# oh baby a triple
data = pd.merge(
        pd.merge(series.iloc[:,0:3],
             pd.merge(product, industry,
                      on='industry_code', how='outer'),
                 on=["industry_code","product_code"], how="outer"),
        out, on="series_id", how="right", suffixes=["sup", " "])

# Series_id has empty spaces at the end.
data.series_id = [x.replace(" ", "") for x in data.series_id ]

# %%
data.sample(15)
# Out:
#                  series_id industry_code product_code  \
# 647781    PCU325199325199S        325199      325199S
# 412833    PCU315110315110S        315110      315110S
# 1058475   PCU332618332618P        332618      332618P
# 903725   PCU33111033111063        331110     33111063
# 584763   PCU32311K32311K65        32311K     32311K65
# 1340375   PCU3344123344120        334412      3344120
# 1242698    PCU333618333618        333618       333618
# 181458    PCU3114213114211        311421      3114211
# 1637107  PCU33993033993027        339930     33993027
# 1596523    PCU337910337910        337910       337910
# 1285054   PCU3339923339927        333992      3339927
# 206433   PCU311511311511SS        311511     311511SS
# 122859     PCU311119311119        311119       311119
# 1309056   PCU3339993339991        333999      3339991
# 1147481   PCU3331313331311        333131      3331311
#
#                                               product_name  \
# 647781                                  Secondary products
# 412833                                  Secondary products
# 1058475                                   Primary products
# 903725   Ferrosilicon, including briquettes, and other ...
# 584763                    Custom continuous business forms
# 1340375                        Bare printed circuit boards
# 1242698                         Other engine equipment mfg
# 181458                 Canned fruits, excluding baby foods
# 1637107   Nonelectronic games and puzzles, including parts
# 1596523                                       Mattress mfg
# 1285054  Resistance welders, components, accessories, a...
# 206433                                  Secondary products
# 122859                     Other animal food manufacturing
# 1309056          Filters and strainers, except fluid power
# 1147481  Underground mining machinery (except parts sol...
#
#                                              industry_name  year  period  \
# 647781      All other basic organic chemical manufacturing  1993      10
# 412833                              Hosiery and sock mills  2013       5
# 1058475                  Other fabricated wire product mfg  2012       2
# 903725                                Iron and steel mills  1947       3
# 584763       Commercial printing (except screen and books)  2008       2
# 1340375                     Bare printed circuit board mfg  2014       3
# 1242698                         Other engine equipment mfg  1981       9
# 181458                         Fruit and vegetable canning  2004       3
# 1637107                            Doll, toy, and game mfg  2010       2
# 1596523                                       Mattress mfg  2006       3
# 1285054                Welding and soldering equipment mfg  1980       7
# 206433                            Fluid milk manufacturing  1983       2
# 122859                     Other animal food manufacturing  2003      10
# 1309056  All other miscellaneous general purpose machin...  2006       6
# 1147481                 Mining machinery and equipment mfg  2005       5
#
#          value      industry minimum  frompresent  age       date
# 647781   115.1     Chemicals    1967           24   26 1993-10-01
# 412833   101.8       Apparel    1967            4   46 2013-05-01
# 1058475  213.7       Current    1967            5   45 2012-02-01
# 903725    18.9  PrimaryMetal    1967           70  -20 1947-03-01
# 584763   242.6      Printing    1967            9   41 2008-02-01
# 1340375  109.7       Current    1967            3   47 2014-03-01
# 1242698   92.2     Machinery    1967           36   14 1981-09-01
# 181458   148.6          Food    1967           13   37 2004-03-01
# 1637107  110.4       Current    1967            7   43 2010-02-01
# 1596523  169.1     Furniture    1967           11   39 2006-03-01
# 1285054   77.4     Machinery    1967           37   13 1980-07-01
# 206433    98.8          Food    1967           34   16 1983-02-01
# 122859   101.8          Food    1967           14   36 2003-10-01
# 1309056  159.4     Machinery    1967           11   39 2006-06-01
# 1147481  201.3       Current    1967           12   38 2005-05-01

# %%
[print(y, x.shape) for (x,y) in [(industry, 'industry_df'), (product, 'product_df'),
                                 (industry, 'industry_df'),(out, 'main_dataset')]]
print("\nUnique Categories:")
print("Unique Product Category Count:", len(product.product_name.unique()))
print("Unique Industry Category Count:", len(industry.industry_name.unique()))
print("Data Unique Industry Count:", len(out.industry.unique()))
print("\nOuter-Merged Dataset:")
[print("{}:".format(x), len(data[x].unique()))for x in ["product_name","industry_name","industry"]]
print("shape:", data.shape)
print("\nMissing? ", data.isnull().values.any())

del out, series, industry, product
# Out:
# industry_df (1064, 2)
# product_df (5172, 3)
# industry_df (1064, 2)
# main_dataset (2086023, 9)
#
# Unique Categories:
# Unique Product Category Count: 3472
# Unique Industry Category Count: 845
# Data Unique Industry Count: 71
#
# Outer-Merged Dataset:
# product_name: 3472
# industry_name: 845
# industry: 71
# shape: (2086023, 13)
#
# Missing?  False

# %%
current = data[data.industry=="Current"]
print("'Current' Industry:")
print("Observation Count:", current.shape[0])
print("Unique Sub-Industries:", len(current.industry_name.unique()))
print("Unique Products:", len(current.product_name.unique()))
# Out:
# 'Current' Industry:
# Observation Count: 827627
# Unique Sub-Industries: 845
# Unique Products: 3465

# %%
# Show the sub-industries and sub-products
industry_unique = pd.DataFrame()
for x in data.industry.unique():
    industry_unique = industry_unique.append({"Industry": x,
                                              "Sub-Industries": len(data[data.industry==x].industry_name.unique()),
                                              "Total Products": len(data[data.industry==x].product_name.unique())},
                                            ignore_index=True)
    #print(x, len(data[data.industry==x].industry_name.unique()), len(data[data.industry==x].product_name.unique()))
    
industry_unique.sort_values(by=["Total Products"], ascending=False, inplace=True)
industry_unique.reset_index(drop=True, inplace=True)
pd.concat([industry_unique[:35], industry_unique[35:].reset_index(drop=True)], axis=1)
# Out:
#                         Industry  Sub-Industries  Total Products  \
# 0                        Current           845.0          3465.0
# 1                      Machinery            55.0           291.0
# 2                           Food            70.0           285.0
# 3                      Chemicals            51.0           234.0
# 4         FabricatedMetalProduct            53.0           228.0
# 5        TransportationEquipment            36.0           159.0
# 6                   PrimaryMetal            30.0           125.0
# 7             NonmetallicMineral            28.0           111.0
# 8                  Miscellaneous            23.0           108.0
# 9         PlasticsRubberProducts            28.0           105.0
# 10           ElectricalMachinery            29.0           102.0
# 11               ComputerProduct            33.0           102.0
# 12                       Apparel            12.0           101.0
# 13                         Paper            19.0            92.0
# 14                          Wood            20.0            82.0
# 15                     Furniture            19.0            77.0
# 16                        Mining            28.0            76.0
# 17                       Textile            10.0            74.0
# 18  AmbulatoryHealthCareServices             9.0            69.0
# 19                     Hospitals             5.0            63.0
# 20                      Printing             6.0            61.0
# 21                     Utilities             7.0            59.0
# 22  ProfessionalandTechnicalServ            10.0            51.0
# 23             InsuranceCarriers             8.0            50.0
# 24                    Publishing            10.0            49.0
# 25               BeverageTobacco            11.0            47.0
# 26                  Construction            12.0            42.0
# 27                       Finance             9.0            42.0
# 28                TextileProduct             9.0            42.0
# 29         PetroleumCoalProducts             9.0            39.0
# 30           RecyclableMaterials             1.0            36.0
# 31            Telecommunications             3.0            35.0
# 32           TruckTransportation            12.0            34.0
# 33  AdministrativeandSupportServ             7.0            34.0
# 34                WholesaleTrade             3.0            32.0
# 35                           NaN             NaN             NaN
#
#                          Industry  Sub-Industries  Total Products
# 0              FoodBeverageStores             6.0            29.0
# 1           TransportationSupport            11.0            28.0
# 2                      RealEstate             9.0            23.0
# 3                         Leather             6.0            22.0
# 4                   PostalService             1.0            22.0
# 5               SportsMusicStores            10.0            21.0
# 6               AirTransportation             7.0            21.0
# 7                   Accommodation             4.0            20.0
# 8             MotorVehicleDealers             8.0            18.0
# 9        RentalandLeasingServices             6.0            18.0
# 10                   Broadcasting             5.0            17.0
# 11                 ClothingStores             6.0            17.0
# 12                  MiningSupport             6.0            16.0
# 13    MiscellaneousStoreRetailers             6.0            15.0
# 14           BuildingGardenStores             9.0            15.0
# 15              NonstoreRetailers             4.0            14.0
# 16   ISPsSearchPortandDataProcess             3.0            14.0
# 17                     Recreation             3.0            14.0
# 18                     aggregates            13.0            13.0
# 19            WaterTransportation             5.0            13.0
# 20                      OilAndGas             3.0            13.0
# 21                   HealthStores             4.0            12.0
# 22    NursingResidentialCareFacil             2.0            12.0
# 23  PremiumsforPropandCasualtyIns             1.0            11.0
# 24                  GeneralStores             5.0            11.0
# 25          CouriersAndMessengers             3.0            10.0
# 26              ElectronicsStores             3.0            10.0
# 27             WarehousingStorage             4.0             9.0
# 28               GasolineStations             3.0             9.0
# 29             RailTransportation             2.0             9.0
# 30                  OtherServices             1.0             7.0
# 31         PipelineTransportation             4.0             7.0
# 32                FurnitureStores             3.0             6.0
# 33     WasteMgtandRemediationServ             2.0             4.0
# 34            EducationalServices             1.0             4.0
# 35             ForestryandLogging             1.0             3.0

# %% [markdown]
# ##  Normalize: Calculate value difference by Series_ID
# <a id="p6"></a>

# %%
# Calculate Difference by period and by Series_Id
data.set_index("date", inplace=True)
data.sort_index(inplace=True)
data['value_diffs'] = data.groupby('series_id')['value'].transform(pd.Series.diff)

# %% [markdown]
# ## Exploratory Data Analysis
# <a id="p7"></a>
#
# Plot value difference over time
# - histograms, or perhaps line plots by industry?

# %%
#data.loc[(data["value_diffs"] > 1000) | (data["value_diffs"] < -1000), :]
data.loc[data.series_id== "PCU33441333441312", "value_diffs"].hist()

# %%
sns.tsplot(data.loc[data.industry== "ForestryandLogging", unit='Kind', condition='Company', value='Price')

# %%
data.loc[~(data.series_id == "PCU33441333441312"), ["value_diffs"]].plot(legend=False) #hist(bins=30)

# %%
sns.kdeplot(data.loc[~(data.series_id == "PCU33441333441312"), ["value_diffs"]], shade=True);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-86de545229f0> in <module>()
# ----> 1 sns.kdeplot(data.loc[~(data.series_id == "PCU33441333441312"), ["value_diffs"]], shade=True);
#
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     633         bivariate = True
#     634         x = data.iloc[:, 0].values
# --> 635         y = data.iloc[:, 1].values
#     636     elif data2 is not None:
#     637         bivariate = True
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1660     def _getitem_tuple(self, tup):
#    1661
# -> 1662         self._has_valid_tuple(tup)
#    1663         try:
#    1664             return self._getitem_lowerdim(tup)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     187             if i >= self.obj.ndim:
#     188                 raise IndexingError('Too many indexers')
# --> 189             if not self._has_valid_type(k, i):
#     190                 raise ValueError("Location based indexing can only have [%s] "
#     191                                  "types" % self._valid_types)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1595             return True
#    1596         elif is_integer(key):
# -> 1597             return self._is_valid_integer(key, axis)
#    1598         elif is_list_like_indexer(key):
#    1599             return self._is_valid_list_like(key, axis)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1636         l = len(ax)
#    1637         if key >= l or key < -l:
# -> 1638             raise IndexError("single positional indexer is out-of-bounds")
#    1639         return True
#    1640
#
# IndexError: single positional indexer is out-of-bounds

# %%
data["value_diffs"].plot()

# %% [markdown]
# ## Output Processed Data

# %%
data.to_csv("Aggregated_BLS_Producer_Price.csv")
